# %% [markdown]
# # MCMC Fitting the absorption profile to an absorption line
#
# This example conducts HMC-NUTS fitting to a mock absorption line. We use the absorption model based on Tepper
# approximation of Voigt profile, lpf.FAbsVRewofz in exojax.lpf (line profile functions) module.
#
# HMC-NUTS: Hamiltonian Monte Carlo No-U-Turn Sample using numpyro

# %%
# %load_ext autoreload
# %autoreload 2

# importing lpf modile in exojax.spec
from exojax.spec import lpf
from exojax.spec import absorption
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import arviz

import numpy as np
import jax.numpy as jnp
from jax import random
from jax.lax import map

import numpyro.distributions as dist
import numpyro
from numpyro.infer import MCMC, NUTS
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi

plt.style.use('bmh')
#numpyro.set_platform("cpu")
#numpyro.set_platform("gpu")

# %%
# generating mock absorption data
np.random.seed(34)
N=20
nuarr=jnp.linspace(-10,10,N)
sigin=0.01
sDfix = jnp.array(1.0)
gLfix = jnp.array(0.5)
Afix = jnp.array(1.0)
nu0fix = 0.7
data=lpf.FAbsVRewofzx(nuarr-nu0fix,sDfix,gLfix,Afix)+np.random.normal(0,sigin,size=N)

# %%
# Here is a mock dataset
plt.plot(nuarr,data,"+",color="C1")
plt.xlabel("$\\nu$")
plt.show()

# %%
#probabilistic model using numpyro
def model(nu,y):
    A = numpyro.sample('A', dist.Uniform(0.5,1.5))
    sD = numpyro.sample('sD', dist.Exponential(1.))
    gL = numpyro.sample('gL', dist.Exponential(1.))
    sigma = numpyro.sample('sigma', dist.Exponential(1.))
    nu0 = numpyro.sample('nu0', dist.Uniform(-5,5))
    mu = lpf.FAbsVRewofzx(nu-nu0,sD,gL,A)
    numpyro.sample('y', dist.Normal(mu, sigma), obs=y)

# %%
# OK, a HMC-NUTS!
# Our model, lpf.FAbsVRewofz, is compatible to jax. Autograd works. We can perform a HMC-NUTS.
rng_key = random.PRNGKey(0)
rng_key, rng_key_ = random.split(rng_key)
num_warmup, num_samples = 1000, 2000

kernel = NUTS(model)
mcmc = MCMC(kernel, num_warmup, num_samples)
mcmc.run(rng_key_, nu=nuarr, y=data)
mcmc.print_summary()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-8-dddb92f5a9cc> in <module>
#       8 mcmc = MCMC(kernel, num_warmup, num_samples)
# ----> 9 mcmc.run(rng_key_, nu=nuarr, y=data)
#      10 mcmc.print_summary()
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     448         if self.num_chains == 1:
# --> 449             states_flat, last_state = partial_map_fn(map_args)
#     450             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     331                                     progbar_desc=partial(get_progbar_desc_str, lower_idx),
# --> 332                                     diagnostics_fn=diagnostics)
#     333         states, last_val = collect_vals
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in fori_collect(lower, upper, body_fun, init_val, transform, progbar, return_last_val, collection_size, **progbar_opts)
#     225                 for i in t:
# --> 226                     vals = jit(_body_fn)(i, vals)
#     227                     t.set_description(progbar_desc(i), refresh=False)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in _body_fn(i, vals)
#     206         val, collection, lower_idx = vals
# --> 207         val = body_fun(val)
#     208         i = jnp.where(i >= lower_idx, i - lower_idx, 0)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in _sample_fn_nojit_args(state, sampler, args, kwargs)
#     179     # state is a tuple of size 1 - containing HMCState
# --> 180     return sampler.sample(state[0], args, kwargs),
#     181
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in sample(self, state, model_args, model_kwargs)
#     495         """
# --> 496         return self._sample_fn(state, model_args, model_kwargs)
#     497
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in sample_kernel(hmc_state, model_args, model_kwargs)
#     310                                                                     model_kwargs,
# --> 311                                                                     rng_key_transition)
#     312         # not update adapt_state after warmup phase
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in _nuts_next(step_size, inverse_mass_matrix, vv_state, model_args, model_kwargs, rng_key)
#     278                                  max_delta_energy=max_delta_energy,
# --> 279                                  max_tree_depth=max_treedepth)
#     280         accept_prob = binary_tree.sum_accept_probs / binary_tree.num_proposals
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in build_tree(verlet_update, kinetic_fn, verlet_state, inverse_mass_matrix, step_size, rng_key, max_delta_energy, max_tree_depth)
#     714     state = (tree, rng_key)
# --> 715     tree, _ = while_loop(_cond_fn, _body_fn, state)
#     716     return tree
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in while_loop(cond_fun, body_fun, init_val)
#     121     else:
# --> 122         return lax.while_loop(cond_fun, body_fun, init_val)
#     123
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in while_loop(cond_fun, body_fun, init_val)
#     284   # necessary, a second time with modified init values.
# --> 285   init_vals, init_avals, body_jaxpr, in_tree, *rest = _create_jaxpr(init_val)
#     286   new_init_vals, changed = _promote_weak_typed_inputs(init_vals, init_avals, body_jaxpr.out_avals)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init_val)
#     270     cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(cond_fun, in_tree, init_avals)
# --> 271     body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(body_fun, in_tree, init_avals)
#     272     if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _body_fn(state)
#     710                             going_right, doubling_key, energy_current, max_delta_energy,
# --> 711                             r_ckpts, r_sum_ckpts)
#     712         return tree, key
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _double_tree(current_tree, vv_update, kinetic_fn, inverse_mass_matrix, step_size, going_right, rng_key, energy_current, max_delta_energy, r_ckpts, r_sum_ckpts)
#     569                                         going_right, key, energy_current, max_delta_energy,
# --> 570                                         r_ckpts, r_sum_ckpts)
#     571
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _iterative_build_subtree(prototype_tree, vv_update, kinetic_fn, inverse_mass_matrix, step_size, going_right, rng_key, energy_current, max_delta_energy, r_ckpts, r_sum_ckpts)
#     656         _body_fn,
# --> 657         (basetree, False, r_ckpts, r_sum_ckpts, rng_key)
#     658     )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in while_loop(cond_fun, body_fun, init_val)
#     121     else:
# --> 122         return lax.while_loop(cond_fun, body_fun, init_val)
#     123
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in while_loop(cond_fun, body_fun, init_val)
#     284   # necessary, a second time with modified init values.
# --> 285   init_vals, init_avals, body_jaxpr, in_tree, *rest = _create_jaxpr(init_val)
#     286   new_init_vals, changed = _promote_weak_typed_inputs(init_vals, init_avals, body_jaxpr.out_avals)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init_val)
#     270     cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(cond_fun, in_tree, init_avals)
# --> 271     body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(body_fun, in_tree, init_avals)
#     272     if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _body_fn(state)
#     626         new_leaf = _build_basetree(vv_update, kinetic_fn, z, r, z_grad, inverse_mass_matrix, step_size,
# --> 627                                    going_right, energy_current, max_delta_energy)
#     628         new_tree = cond(current_tree.num_proposals == 0,
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _build_basetree(vv_update, kinetic_fn, z, r, z_grad, inverse_mass_matrix, step_size, going_right, energy_current, max_delta_energy)
#     537         inverse_mass_matrix,
# --> 538         (z, r, energy_current, z_grad),
#     539     )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in update_fn(step_size, inverse_mass_matrix, state)
#     208         z = tree_multimap(lambda z, r_grad: z + step_size * r_grad, z, r_grad)  # z(n+1)
# --> 209         potential_energy, z_grad = value_and_grad(potential_fn)(z)
#     210         r = tree_multimap(lambda r, z_grad: r - 0.5 * step_size * z_grad, r, z_grad)  # r(n+1)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     156     # no param is needed for log_density computation because we already substitute
# --> 157     log_joint, model_trace = log_density_(substituted_model, model_args, model_kwargs, {})
#     158     return - log_joint
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      49     model = substitute(model, data=params)
# ---> 50     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      51     log_joint = jnp.array(0.)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     157         """
# --> 158         self(*args, **kwargs)
#     159         return self.trace
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# <ipython-input-7-b6ed5fcf546f> in model(nu, y)
#       7     nu0 = numpyro.sample('nu0', dist.Uniform(-5,5))
# ----> 8     mu = lpf.FAbsVRewofzx(nu-nu0,sD,gL,A)
#       9     numpyro.sample('y', dist.Normal(mu, sigma), obs=y)
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in FAbsVRewofzx(nu, sigmaD, gammaL, A)
#     117     """
# --> 118     tau=A*VoigtRewofzx(nu,sigmaD,gammaL)
#     119     f=jnp.exp(-tau)
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in VoigtRewofzx(nu, sigmaD, gammaL)
#      88     vrewofz=vmap(rewofzx,(0,None),0)
# ---> 89     v=sfac*vrewofz(sfac*nu,sfac*gammaL)/jnp.sqrt(jnp.pi)
#      90     return v
#
# FilteredStackTrace: AssertionError: length mismatch: [1, 5]
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-dddb92f5a9cc> in <module>
#       7 kernel = NUTS(model)
#       8 mcmc = MCMC(kernel, num_warmup, num_samples)
# ----> 9 mcmc.run(rng_key_, nu=nuarr, y=data)
#      10 mcmc.print_summary()
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     447         map_args = (rng_key, init_state, init_params)
#     448         if self.num_chains == 1:
# --> 449             states_flat, last_state = partial_map_fn(map_args)
#     450             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     451         else:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     330                                     collection_size=self._collection_params["collection_size"],
#     331                                     progbar_desc=partial(get_progbar_desc_str, lower_idx),
# --> 332                                     diagnostics_fn=diagnostics)
#     333         states, last_val = collect_vals
#     334         # Get first argument of type `HMCState`
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in fori_collect(lower, upper, body_fun, init_val, transform, progbar, return_last_val, collection_size, **progbar_opts)
#     224             with tqdm.trange(upper) as t:
#     225                 for i in t:
# --> 226                     vals = jit(_body_fn)(i, vals)
#     227                     t.set_description(progbar_desc(i), refresh=False)
#     228                     if diagnostics_fn:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     215         backend=backend,
#     216         name=flat_fun.__name__,
# --> 217         donated_invars=donated_invars)
#     218     return tree_unflatten(out_tree(), out)
#     219
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     573
#     574   def process_call(self, primitive, f, tracers, params):
# --> 575     return primitive.impl(f, *tracers, **params)
#     576   process_map = process_call
#     577
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     555 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
#     556   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 557                                *unsafe_map(arg_spec, args))
#     558   try:
#     559     return compiled_fun(*args)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     245       fun.populate_stores(stores)
#     246     else:
# --> 247       ans = call(fun, *args)
#     248       cache[key] = (ans, fun.stores)
#     249
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     630   abstract_args, arg_devices = unzip2(arg_specs)
#     631   if config.omnistaging_enabled:
# --> 632     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(fun, abstract_args)
#     633     if any(isinstance(c, core.Tracer) for c in consts):
#     634       raise core.UnexpectedTracerError("Encountered an unexpected tracer.")
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals)
#    1036     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1037     main.jaxpr_stack = ()  # type: ignore
# -> 1038     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1039     del main
#    1040   return jaxpr, out_avals, consts
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in _body_fn(i, vals)
#     205     def _body_fn(i, vals):
#     206         val, collection, lower_idx = vals
# --> 207         val = body_fun(val)
#     208         i = jnp.where(i >= lower_idx, i - lower_idx, 0)
#     209         collection = ops.index_update(collection, i, ravel_pytree(transform(val))[0])
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/mcmc.py in _sample_fn_nojit_args(state, sampler, args, kwargs)
#     178 def _sample_fn_nojit_args(state, sampler, args, kwargs):
#     179     # state is a tuple of size 1 - containing HMCState
# --> 180     return sampler.sample(state[0], args, kwargs),
#     181
#     182
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in sample(self, state, model_args, model_kwargs)
#     494         :return: Next `state` after running HMC.
#     495         """
# --> 496         return self._sample_fn(state, model_args, model_kwargs)
#     497
#     498
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in sample_kernel(hmc_state, model_args, model_kwargs)
#     309                                                                     model_args,
#     310                                                                     model_kwargs,
# --> 311                                                                     rng_key_transition)
#     312         # not update adapt_state after warmup phase
#     313         adapt_state = cond(hmc_state.i < wa_steps,
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc.py in _nuts_next(step_size, inverse_mass_matrix, vv_state, model_args, model_kwargs, rng_key)
#     277                                  inverse_mass_matrix, step_size, rng_key,
#     278                                  max_delta_energy=max_delta_energy,
# --> 279                                  max_tree_depth=max_treedepth)
#     280         accept_prob = binary_tree.sum_accept_probs / binary_tree.num_proposals
#     281         num_steps = binary_tree.num_proposals
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in build_tree(verlet_update, kinetic_fn, verlet_state, inverse_mass_matrix, step_size, rng_key, max_delta_energy, max_tree_depth)
#     713
#     714     state = (tree, rng_key)
# --> 715     tree, _ = while_loop(_cond_fn, _body_fn, state)
#     716     return tree
#     717
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in while_loop(cond_fun, body_fun, init_val)
#     120         return val
#     121     else:
# --> 122         return lax.while_loop(cond_fun, body_fun, init_val)
#     123
#     124
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in while_loop(cond_fun, body_fun, init_val)
#     283   # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     284   # necessary, a second time with modified init values.
# --> 285   init_vals, init_avals, body_jaxpr, in_tree, *rest = _create_jaxpr(init_val)
#     286   new_init_vals, changed = _promote_weak_typed_inputs(init_vals, init_avals, body_jaxpr.out_avals)
#     287   if changed:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init_val)
#     269     init_avals = tuple(_map(_abstractify, init_vals))
#     270     cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(cond_fun, in_tree, init_avals)
# --> 271     body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(body_fun, in_tree, init_avals)
#     272     if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#     273       msg = "cond_fun must return a boolean scalar, but got pytree {}."
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      69 @cache()
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      73   return closed_jaxpr, consts, out_tree
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      64 def _initial_style_open_jaxpr(fun: Callable, in_tree, in_avals):
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#      68
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_dynamic(fun, in_avals)
#    1007     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1008     main.jaxpr_stack = ()  # type: ignore
# -> 1009     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1010     del main
#    1011   return jaxpr, out_avals, consts
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _body_fn(state)
#     709         tree = _double_tree(tree, verlet_update, kinetic_fn, inverse_mass_matrix, step_size,
#     710                             going_right, doubling_key, energy_current, max_delta_energy,
# --> 711                             r_ckpts, r_sum_ckpts)
#     712         return tree, key
#     713
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _double_tree(current_tree, vv_update, kinetic_fn, inverse_mass_matrix, step_size, going_right, rng_key, energy_current, max_delta_energy, r_ckpts, r_sum_ckpts)
#     568                                         inverse_mass_matrix, step_size,
#     569                                         going_right, key, energy_current, max_delta_energy,
# --> 570                                         r_ckpts, r_sum_ckpts)
#     571
#     572     return _combine_tree(current_tree, new_tree, inverse_mass_matrix, going_right, transition_key,
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _iterative_build_subtree(prototype_tree, vv_update, kinetic_fn, inverse_mass_matrix, step_size, going_right, rng_key, energy_current, max_delta_energy, r_ckpts, r_sum_ckpts)
#     655         _cond_fn,
#     656         _body_fn,
# --> 657         (basetree, False, r_ckpts, r_sum_ckpts, rng_key)
#     658     )
#     659     # update depth and turning condition
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in while_loop(cond_fun, body_fun, init_val)
#     120         return val
#     121     else:
# --> 122         return lax.while_loop(cond_fun, body_fun, init_val)
#     123
#     124
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in while_loop(cond_fun, body_fun, init_val)
#     283   # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     284   # necessary, a second time with modified init values.
# --> 285   init_vals, init_avals, body_jaxpr, in_tree, *rest = _create_jaxpr(init_val)
#     286   new_init_vals, changed = _promote_weak_typed_inputs(init_vals, init_avals, body_jaxpr.out_avals)
#     287   if changed:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init_val)
#     269     init_avals = tuple(_map(_abstractify, init_vals))
#     270     cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(cond_fun, in_tree, init_avals)
# --> 271     body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(body_fun, in_tree, init_avals)
#     272     if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#     273       msg = "cond_fun must return a boolean scalar, but got pytree {}."
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      69 @cache()
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      73   return closed_jaxpr, consts, out_tree
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      64 def _initial_style_open_jaxpr(fun: Callable, in_tree, in_avals):
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#      68
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_dynamic(fun, in_avals)
#    1007     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1008     main.jaxpr_stack = ()  # type: ignore
# -> 1009     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1010     del main
#    1011   return jaxpr, out_avals, consts
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _body_fn(state)
#     625         z, r, z_grad = _get_leaf(current_tree, going_right)
#     626         new_leaf = _build_basetree(vv_update, kinetic_fn, z, r, z_grad, inverse_mass_matrix, step_size,
# --> 627                                    going_right, energy_current, max_delta_energy)
#     628         new_tree = cond(current_tree.num_proposals == 0,
#     629                         new_leaf,
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in _build_basetree(vv_update, kinetic_fn, z, r, z_grad, inverse_mass_matrix, step_size, going_right, energy_current, max_delta_energy)
#     536         step_size,
#     537         inverse_mass_matrix,
# --> 538         (z, r, energy_current, z_grad),
#     539     )
#     540
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/hmc_util.py in update_fn(step_size, inverse_mass_matrix, state)
#     207         r_grad = grad(kinetic_fn, argnums=1)(inverse_mass_matrix, r)
#     208         z = tree_multimap(lambda z, r_grad: z + step_size * r_grad, z, r_grad)  # z(n+1)
# --> 209         potential_energy, z_grad = value_and_grad(potential_fn)(z)
#     210         r = tree_multimap(lambda r, z_grad: r - 0.5 * step_size * z_grad, r, z_grad)  # r(n+1)
#     211         return IntegratorState(z, r, potential_energy, z_grad)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     808     tree_map(partial(_check_input_dtype_grad, holomorphic, allow_int), dyn_args)
#     809     if not has_aux:
# --> 810       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     811     else:
#     812       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1839   if not has_aux:
#    1840     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1841     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1842     out_tree = out_tree()
#    1843   else:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     111 def vjp(traceable, primals, has_aux=False):
#     112   if not has_aux:
# --> 113     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     114   else:
#     115     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      98   _, in_tree = tree_flatten(((primals, primals), {}))
#      99   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 100   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     101   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     102   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     402   with core.new_main(JaxprTrace) as main:
#     403     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 404     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     405     assert not env
#     406     del main
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     155     substituted_model = substitute(model, substitute_fn=partial(_unconstrain_reparam, params))
#     156     # no param is needed for log_density computation because we already substitute
# --> 157     log_joint, model_trace = log_density_(substituted_model, model_args, model_kwargs, {})
#     158     return - log_joint
#     159
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      48     """
#      49     model = substitute(model, data=params)
# ---> 50     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      51     log_joint = jnp.array(0.)
#      52     for site in model_trace.values():
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     156         :return: `OrderedDict` containing the execution trace.
#     157         """
# --> 158         self(*args, **kwargs)
#     159         return self.trace
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# <ipython-input-7-b6ed5fcf546f> in model(nu, y)
#       6     sigma = numpyro.sample('sigma', dist.Exponential(1.))
#       7     nu0 = numpyro.sample('nu0', dist.Uniform(-5,5))
# ----> 8     mu = lpf.FAbsVRewofzx(nu-nu0,sD,gL,A)
#       9     numpyro.sample('y', dist.Normal(mu, sigma), obs=y)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     215         backend=backend,
#     216         name=flat_fun.__name__,
# --> 217         donated_invars=donated_invars)
#     218     return tree_unflatten(out_tree(), out)
#     219
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     289     update_params = call_param_updaters.get(call_primitive)
#     290     new_params = update_params(params, nz_tangents) if update_params else params
# --> 291     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     292     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     293     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     180                   for pval, is_mapped in zip(in_pvals, params['mapped_invars'])]
#     181     jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
# --> 182         f, in_pvals, partial(primitive.bind, **params))
#     183     if primitive.map_primitive:
#     184       unmapped_aval = partial(core.unmapped_aval, params['axis_size'])
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app)
#     279     f = trace_to_subjaxpr(f, self.main, False)
#     280     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 281     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     282     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     283     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     953   def process_call(self, call_primitive, f, tracers, params):
#     954     in_avals = [t.aval for t in tracers]
# --> 955     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#     956     if not jaxpr.eqns:
#     957       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in FAbsVRewofzx(nu, sigmaD, gammaL, A)
#     116
#     117     """
# --> 118     tau=A*VoigtRewofzx(nu,sigmaD,gammaL)
#     119     f=jnp.exp(-tau)
#     120     return f
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     215         backend=backend,
#     216         name=flat_fun.__name__,
# --> 217         donated_invars=donated_invars)
#     218     return tree_unflatten(out_tree(), out)
#     219
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     289     update_params = call_param_updaters.get(call_primitive)
#     290     new_params = update_params(params, nz_tangents) if update_params else params
# --> 291     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     292     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     293     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     180                   for pval, is_mapped in zip(in_pvals, params['mapped_invars'])]
#     181     jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
# --> 182         f, in_pvals, partial(primitive.bind, **params))
#     183     if primitive.map_primitive:
#     184       unmapped_aval = partial(core.unmapped_aval, params['axis_size'])
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app)
#     279     f = trace_to_subjaxpr(f, self.main, False)
#     280     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 281     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     282     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     283     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     953   def process_call(self, call_primitive, f, tracers, params):
#     954     in_avals = [t.aval for t in tracers]
# --> 955     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#     956     if not jaxpr.eqns:
#     957       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in VoigtRewofzx(nu, sigmaD, gammaL)
#      87     sfac=1.0/(jnp.sqrt(2)*sigmaD)
#      88     vrewofz=vmap(rewofzx,(0,None),0)
# ---> 89     v=sfac*vrewofz(sfac*nu,sfac*gammaL)/jnp.sqrt(jnp.pi)
#      90     return v
#      91
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in batched_fun(*args)
#    1228                               lambda: flatten_axes("vmap out_axes", out_tree(),
#    1229                                                    out_axes),
# -> 1230                               axis_name=axis_name)
#    1231     return tree_unflatten(out_tree(), out_flat)
#    1232
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/batching.py in batch(fun, in_vals, in_dims, out_dim_dests, axis_name)
#      34   # executes a batched version of `fun` following out_dim_dests
#      35   batched_fun = batch_fun(fun, in_dims, out_dim_dests, axis_name=axis_name)
# ---> 36   return batched_fun.call_wrapped(*in_vals)
#      37
#      38 @lu.transformation_with_aux
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/jax/custom_derivatives.py in __call__(self, *args, **kwargs)
#     469     if _initial_style_staging():
#     470       out_flat = custom_vjp_call_jaxpr(flat_fun, flat_fwd, flat_bwd,
# --> 471                                        *args_flat, out_trees=out_trees)
#     472       out_tree = out_tree()
#     473     else:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/custom_derivatives.py in custom_vjp_call_jaxpr(fun, fwd, bwd, out_trees, *args)
#     536   return custom_vjp_call_jaxpr_p.bind(*args, fun_jaxpr=fun_jaxpr,
#     537                                       fwd_jaxpr_thunk=fwd_jaxpr_thunk, bwd=bwd,
# --> 538                                       out_trees=out_trees)
#     539
#     540 def _custom_vjp_call_jaxpr_impl(*args, fun_jaxpr, **_):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **params)
#     261     top_trace = find_top_trace(args)
#     262     tracers = map(top_trace.full_raise, args)
# --> 263     out = top_trace.process_primitive(self, tracers, params)
#     264     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     265
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     157     val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     158     if primitive.multiple_results:
# --> 159       return map(partial(BatchTracer, self), val_out, dim_out)
#     160     else:
#     161       return BatchTracer(self, val_out, dim_out)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/util.py in safe_map(f, *args)
#      32   n = len(args[0])
#      33   for arg in args[1:]:
# ---> 34     assert len(arg) == n, 'length mismatch: {}'.format(list(map(len, args)))
#      35   return list(map(f, *args))
#      36
#
# AssertionError: length mismatch: [1, 5]

# %%
#arviz is superuseful to check chains
arviz.plot_trace(mcmc, var_names=["A", "gL", "sD","nu0","sigma"])
plt.show()

# %%
#cool and flexible corner plot in arviz. You can also try kind='hexbin' instead of 'kde' for instance.
#arviz.plot_pair(arviz.from_numpyro(mcmc),kind='kde',divergences=True)
refs={}
refs["A"]=Afix
refs["sD"]=sDfix
refs["gL"]=gLfix
refs["sigma"]=sigin
refs["nu0"]=nu0fix
arviz.plot_pair(arviz.from_numpyro(mcmc),kind='kde',divergences=False,\
                marginals=True,
                reference_values=refs,
               reference_values_kwargs={'color':"red", "marker":"o", "markersize":12}) 
plt.show()

# %%
# further check of chain
arviz.plot_rank(arviz.from_numpyro(mcmc))
plt.show()

# %%
# generating predictions
# hpdi is "highest posterior density interval"
posterior_sample = mcmc.get_samples()
pred = Predictive(model,posterior_sample)
nu_ = jnp.linspace(-12,12,100)
predictions = pred(rng_key_,nu=nu_,y=None)
median_mu = jnp.median(predictions["y"],axis=0)
hpdi_mu = hpdi(predictions["y"], 0.9)

# %%
# final plot of median and 90% credible area of the prediction

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 3))
ax.plot(nu_,median_mu,color="C0")
ax.plot(nuarr,data,"+",color="C1",label="data")
ax.fill_between(nu_, hpdi_mu[0], hpdi_mu[1], alpha=0.3, interpolate=True,color="C0",
                label="90% area")
plt.xlabel("$\\nu$")
plt.legend()
plt.savefig("../../documents/figures/mcmc_fitting_absorption.png")
plt.show()

# %%
#when using numatrix
np.random.seed(38)
N=1000
nur=1000
nuarr=jnp.linspace(-nur,nur,N)
sigin=0.01
sDfix = jnp.array(1.0)
gLfix = jnp.array(0.5)

Nmol=100
hatnufix = (np.random.rand(Nmol)-0.5)*nur*2
Sfix=np.random.rand(Nmol)
Afix=jnp.array(0.03)
nu0fix = 0.7
#f = lambda nu: lpf.MultiAbsVTc(nu-nu0fix,sDfix,gLfix,Afix,Sfix,hatnufix)

numatrix=lpf.make_numatrix(nuarr,hatnufix,nu0fix)

(lpf.VoigtRewofz(numatrix.flatten(),sDfix,gLfix)).reshape(np.shape(numatrix))
# Out:
# DeviceArray([[2.68264358e-07, 2.69664326e-07, 2.71075294e-07, ...,
#               1.05929580e-07, 1.05584398e-07, 1.05240908e-07],
#              [5.37904512e-08, 5.39158727e-08, 5.40417453e-08, ...,
#               2.09119503e-06, 2.06116965e-06, 2.03178774e-06],
#              [4.45975346e-08, 4.46922073e-08, 4.47871926e-08, ...,
#               1.39314507e-05, 1.34237907e-05, 1.29434093e-05],
#              ...,
#              [6.38269171e-07, 6.43417820e-07, 6.48629566e-07, ...,
#               7.10535915e-08, 7.08638836e-08, 7.06749290e-08],
#              [1.82488554e-06, 1.84988153e-06, 1.87539626e-06, ...,
#               5.50274670e-08, 5.48981376e-08, 5.47692665e-08],
#              [2.39021318e-07, 2.40198489e-07, 2.41384413e-07, ...,
#               1.14304484e-07, 1.13917601e-07, 1.13532700e-07]],            dtype=float32)
