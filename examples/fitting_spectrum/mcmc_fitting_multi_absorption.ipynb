# %% [markdown]
# # MCMC Fitting the absorption profile to an absorption line
#
# This example conducts HMC-NUTS fitting to a mock absorption line. We use the absorption model based on Tepper
# approximation of Voigt profile, lpf.FAbsVTc in exojax.lpf (line profile functions) module.
#
# HMC-NUTS: Hamiltonian Monte Carlo No-U-Turn Sample using numpyro

# %%
# %load_ext autoreload
# %autoreload 2

# importing lpf modile in exojax.spec
from exojax.spec import lpf

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import arviz

import numpy as np
import jax.numpy as jnp
from jax import random
from jax import jit
from jax.lax import map

import numpyro.distributions as dist
import numpyro
from numpyro.infer import MCMC, NUTS
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi

plt.style.use('bmh')
numpyro.set_platform("cpu")
#numpyro.set_platform("gpu")
# Out:
# /home/kawahara/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /home/kawahara/anaconda3/lib/python3.7/site-packages/distributed/utils.py:139: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [Errno 101] Network is unreachable
#   RuntimeWarning,

# %%
# generating mock absorption data
np.random.seed(38)
N=1000
nur=500
nuarr=jnp.linspace(-nur,nur,N)
sigin=0.01
sDfix = jnp.array(1.0)
gLfix = jnp.array(0.5)

Nmol=100
hatnufix = (np.random.rand(Nmol)-0.5)*nur*2
Sfix=np.random.rand(Nmol)
Afix=jnp.array(0.03)
nu0fix = 0.7
#f = lambda nu: lpf.MultiAbsVTc(nu-nu0fix,sDfix,gLfix,Afix,Sfix,hatnufix)

numatrix=lpf.make_numatrix(nuarr,hatnufix,nu0fix)
spec=lpf.MultiAbsVTc(numatrix,sDfix,gLfix,Afix,Sfix)
data=spec+np.random.normal(0,sigin,size=N)

# %%
# Here is a mock dataset
fig=plt.figure(figsize=(15,3))
plt.plot(nuarr,data,"+",color="C1")
for hatnu in hatnufix:
    plt.axvline(hatnu+nu0fix,alpha=0.3)
plt.xlabel("$\\nu$")
plt.show()

# %%
#probabilistic model using numpyro
def model(nu,y):
    A = numpyro.sample('A', dist.Uniform(0.0,1.0))
    sD = numpyro.sample('sD', dist.Exponential(1.))
    gL = numpyro.sample('gL', dist.Exponential(1.))
    sigma = numpyro.sample('sigma', dist.Exponential(1.))
    nu0 = numpyro.sample('nu0', dist.Uniform(-5,5))
    #numatrix=lpf.make_numatrix(nu,hatnufix,nu0)
    numatrix=nu-nu0
    mu = lpf.MultiAbsVTc(numatrix,sD,gL,A,Sfix)
    #mu = lpf.MultiAbsVTc(nu-nu0,sD,gL,A,Sfix,hatnufix)
    numpyro.sample('y', dist.Normal(mu, sigma), obs=y)

# %%
# OK, a HMC-NUTS!
# Our model, lpf.MultiAbsVTc, is compatible to jax. Autograd works. We can perform a HMC-NUTS.
rng_key = random.PRNGKey(0)
rng_key, rng_key_ = random.split(rng_key)
num_warmup, num_samples = 1000, 2000

kernel = NUTS(model)
mcmc = MCMC(kernel, num_warmup, num_samples)
mcmc.run(rng_key_, nu=lpf.make_numatrix(nuarr,hatnufix,0), y=data)
mcmc.print_summary()
# Out:
# sample: 100%|██████████| 3000/3000 [00:44<00:00, 68.07it/s, 7 steps of size 2.70e-01. acc. prob=0.77]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.03      0.00      0.03      0.02      0.04   1203.30      1.00
#         gL      0.42      0.18      0.45      0.10      0.70    730.14      1.00
#        nu0      0.89      0.27      0.92      0.43      1.28    898.99      1.00
#         sD      0.95      0.31      0.88      0.53      1.38    526.06      1.00
#      sigma      0.01      0.00      0.01      0.01      0.01   1034.06      1.00
#
# Number of divergences: 1

# %%
#arviz is superuseful to check chains
arviz.plot_trace(mcmc)
plt.show()

# %%
#cool and flexible corner plot in arviz. You can also try kind='hexbin' instead of 'kde' for instance.
#arviz.plot_pair(arviz.from_numpyro(mcmc),kind='kde',divergences=True)
refs={}
refs["A"]=Afix
refs["sD"]=sDfix
refs["gL"]=gLfix
refs["sigma"]=sigin
refs["nu0"]=nu0fix
arviz.plot_pair(arviz.from_numpyro(mcmc),kind='kde',divergences=False,\
                marginals=True,
                reference_values=refs,
               reference_values_kwargs={'color':"red", "marker":"o", "markersize":12}) 
plt.show()

# %%
# further check of chain
arviz.plot_rank(arviz.from_numpyro(mcmc))
plt.show()

# %%
# generating predictions
# hpdi is "highest posterior density interval"
posterior_sample = mcmc.get_samples()
pred = Predictive(model,posterior_sample)
nu_ = jnp.linspace(-nur,nur,1000)
predictions = pred(rng_key_,nu=lpf.make_numatrix(nu_,jnp.array([0]),0),y=None)
median_mu = jnp.median(predictions["y"],axis=0)
hpdi_mu = hpdi(predictions["y"], 0.9)
# Out:
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-47-35fc65fcae1b> in <module>
#       5 nu_ = jnp.linspace(-nur,nur,1000)
# ----> 6 predictions = pred(rng_key_,nu=lpf.make_numatrix(nu_,jnp.array([0]),0),y=None)
#       7 median_mu = jnp.median(predictions["y"],axis=0)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in __call__(self, rng_key, *args, **kwargs)
#     573                            return_sites=self.return_sites, parallel=self.parallel,
# --> 574                            model_args=args, model_kwargs=kwargs)
#     575
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in _predictive(rng_key, model, posterior_samples, batch_shape, return_sites, parallel, model_args, model_kwargs)
#     474     chunk_size = num_samples if parallel else 1
# --> 475     return soft_vmap(single_prediction, (rng_key, posterior_samples), len(batch_shape), chunk_size)
#     476
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in soft_vmap(fn, xs, batch_ndims, chunk_size)
#     297
# --> 298     ys = lax.map(fn, xs) if num_chunks > 1 else fn(xs)
#     299     map_ndims = int(num_chunks > 1) + int(chunk_size > 1)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in map(f, xs)
#    1898   g = lambda _, x: ((), f(x))
# -> 1899   _, ys = scan(g, (), xs)
#    1900   return ys
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in scan(f, init, xs, length, reverse, unroll)
#    1249   # necessary, a second time with modified init values.
# -> 1250   init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#    1251   new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init)
#    1236     carry_avals = tuple(_map(_abstractify, init_flat))
# -> 1237     jaxpr, consts, out_tree = _initial_style_jaxpr(f, in_tree, carry_avals + x_avals)
#    1238     out_tree_children = out_tree.children()
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in <lambda>(_, x)
#    1897   """
# -> 1898   g = lambda _, x: ((), f(x))
#    1899   _, ys = scan(g, (), xs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in single_prediction(val)
#     458         model_trace = trace(seed(substitute(model, samples), rng_key)).get_trace(
# --> 459             *model_args, **model_kwargs)
#     460         if return_sites is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     157         """
# --> 158         self(*args, **kwargs)
#     159         return self.trace
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# <ipython-input-36-8ba948395243> in model(nu, y)
#       9     numatrix=nu-nu0
# ---> 10     mu = lpf.MultiAbsVTc(numatrix,sD,gL,A,Sfix)
#      11     #mu = lpf.MultiAbsVTc(nu-nu0,sD,gL,A,Sfix,hatnufix)
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in MultiAbsVTc(numatrix, sigmaD, gammaL, A, S)
#     126     """
# --> 127     tau=jnp.dot(VoigtTc(numatrix,sigmaD,gammaL).T,S)
#     128     f=jnp.exp(-A*tau)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in dot(a, b, precision)
#    3172   if _max(a_ndim, b_ndim) <= 2:
# -> 3173     return lax.dot(a, b, precision=precision)
#    3174
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax.py in dot(lhs, rhs, precision)
#     599     raise TypeError("Incompatible shapes for dot: got {} and {}.".format(
# --> 600         lhs.shape, rhs.shape))
#     601
#
# FilteredStackTrace: TypeError: Incompatible shapes for dot: got (1000, 1) and (100,).
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-35fc65fcae1b> in <module>
#       4 pred = Predictive(model,posterior_sample)
#       5 nu_ = jnp.linspace(-nur,nur,1000)
# ----> 6 predictions = pred(rng_key_,nu=lpf.make_numatrix(nu_,jnp.array([0]),0),y=None)
#       7 median_mu = jnp.median(predictions["y"],axis=0)
#       8 hpdi_mu = hpdi(predictions["y"], 0.9)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in __call__(self, rng_key, *args, **kwargs)
#     572         return _predictive(rng_key, model, posterior_samples, self._batch_shape,
#     573                            return_sites=self.return_sites, parallel=self.parallel,
# --> 574                            model_args=args, model_kwargs=kwargs)
#     575
#     576
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in _predictive(rng_key, model, posterior_samples, batch_shape, return_sites, parallel, model_args, model_kwargs)
#     473     rng_key = rng_key.reshape(batch_shape + (2,))
#     474     chunk_size = num_samples if parallel else 1
# --> 475     return soft_vmap(single_prediction, (rng_key, posterior_samples), len(batch_shape), chunk_size)
#     476
#     477
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/util.py in soft_vmap(fn, xs, batch_ndims, chunk_size)
#     296         fn = vmap(fn)
#     297
# --> 298     ys = lax.map(fn, xs) if num_chunks > 1 else fn(xs)
#     299     map_ndims = int(num_chunks > 1) + int(chunk_size > 1)
#     300     ys = tree_map(lambda y: jnp.reshape(y, (-1,) + jnp.shape(y)[map_ndims:])[:batch_size], ys)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in map(f, xs)
#    1897   """
#    1898   g = lambda _, x: ((), f(x))
# -> 1899   _, ys = scan(g, (), xs)
#    1900   return ys
#    1901
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in scan(f, init, xs, length, reverse, unroll)
#    1248   # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#    1249   # necessary, a second time with modified init values.
# -> 1250   init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#    1251   new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#    1252   if changed:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _create_jaxpr(init)
#    1235
#    1236     carry_avals = tuple(_map(_abstractify, init_flat))
# -> 1237     jaxpr, consts, out_tree = _initial_style_jaxpr(f, in_tree, carry_avals + x_avals)
#    1238     out_tree_children = out_tree.children()
#    1239     if len(out_tree_children) != 2:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      69 @cache()
#      70 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals):
# ---> 71   jaxpr, out_avals, consts, out_tree = _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      72   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      73   return closed_jaxpr, consts, out_tree
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_open_jaxpr(fun, in_tree, in_avals)
#      64 def _initial_style_open_jaxpr(fun: Callable, in_tree, in_avals):
#      65   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 66   jaxpr, out_avals, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      67   return jaxpr, out_avals, consts, out_tree()
#      68
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_dynamic(fun, in_avals)
#    1007     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1008     main.jaxpr_stack = ()  # type: ignore
# -> 1009     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1010     del main
#    1011   return jaxpr, out_avals, consts
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in <lambda>(_, x)
#    1896     Mapped values.
#    1897   """
# -> 1898   g = lambda _, x: ((), f(x))
#    1899   _, ys = scan(g, (), xs)
#    1900   return ys
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/infer/util.py in single_prediction(val)
#     457         rng_key, samples = val
#     458         model_trace = trace(seed(substitute(model, samples), rng_key)).get_trace(
# --> 459             *model_args, **model_kwargs)
#     460         if return_sites is not None:
#     461             if return_sites == '':
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     156         :return: `OrderedDict` containing the execution trace.
#     157         """
# --> 158         self(*args, **kwargs)
#     159         return self.trace
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# <ipython-input-36-8ba948395243> in model(nu, y)
#       8     #numatrix=lpf.make_numatrix(nu,hatnufix,nu0)
#       9     numatrix=nu-nu0
# ---> 10     mu = lpf.MultiAbsVTc(numatrix,sD,gL,A,Sfix)
#      11     #mu = lpf.MultiAbsVTc(nu-nu0,sD,gL,A,Sfix,hatnufix)
#      12     numpyro.sample('y', dist.Normal(mu, sigma), obs=y)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     215         backend=backend,
#     216         name=flat_fun.__name__,
# --> 217         donated_invars=donated_invars)
#     218     return tree_unflatten(out_tree(), out)
#     219
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1160
#    1161   def bind(self, fun, *args, **params):
# -> 1162     return call_bind(self, fun, *args, **params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1151   tracers = map(top_trace.full_raise, args)
#    1152   with maybe_new_sublevel(top_trace):
# -> 1153     outs = primitive.process(top_trace, fun, tracers, params)
#    1154   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1155
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1163
#    1164   def process(self, trace, fun, tracers, params):
# -> 1165     return trace.process_call(self, fun, tracers, params)
#    1166
#    1167   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     953   def process_call(self, call_primitive, f, tracers, params):
#     954     in_avals = [t.aval for t in tracers]
# --> 955     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#     956     if not jaxpr.eqns:
#     957       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1017     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1018     in_tracers = map(trace.new_arg, in_avals)
# -> 1019     ans = fun.call_wrapped(*in_tracers)
#    1020     out_tracers = map(trace.full_raise, ans)
#    1021   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     154
#     155     try:
# --> 156       ans = self.f(*args, **dict(self.params, **kwargs))
#     157     except:
#     158       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/lpf.py in MultiAbsVTc(numatrix, sigmaD, gammaL, A, S)
#     125
#     126     """
# --> 127     tau=jnp.dot(VoigtTc(numatrix,sigmaD,gammaL).T,S)
#     128     f=jnp.exp(-A*tau)
#     129     return f
#
# ~/anaconda3/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in dot(a, b, precision)
#    3171     return lax.mul(a, b)
#    3172   if _max(a_ndim, b_ndim) <= 2:
# -> 3173     return lax.dot(a, b, precision=precision)
#    3174
#    3175   if b_ndim == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/lax/lax.py in dot(lhs, rhs, precision)
#     598   else:
#     599     raise TypeError("Incompatible shapes for dot: got {} and {}.".format(
# --> 600         lhs.shape, rhs.shape))
#     601
#     602
#
# TypeError: Incompatible shapes for dot: got (1000, 1) and (100,).

# %%
# final plot of median and 90% credible area of the prediction

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
ax.plot(nu_,median_mu,color="C0")
ax.plot(nuarr,data,"+",color="C1",label="data")
ax.fill_between(nu_, hpdi_mu[0], hpdi_mu[1], alpha=0.3, interpolate=True,color="C0",
                label="90% area")
plt.xlabel("$\\nu$")
plt.legend()
plt.savefig("../../documents/figures/mcmc_fitting_multi_absorption.png")
plt.show()
