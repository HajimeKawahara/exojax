# %% [markdown]
# # Simple Usage

# %% [markdown]
# ## 1. Voigt profile

# %%
import numpy
import matplotlib.pyplot as plt
from exojax.spec import voigt

# %%
x=numpy.linspace(-10,10,100) 
y=voigt(x,1.0,2.0) #sigma_D=1.0, gamma_L=2.0

# %%
plt.plot(x,y)

# %% [markdown]
# ## 2. Cross section

# %%
 from exojax.spec import AutoXS

# %% [markdown]
# exojax automatically downloads a molecular database, convert it to the feather format and save it in .database directory.

# %%
nus=numpy.linspace(1900.0,2300.0,40000,dtype=numpy.float64) #wavenumber (cm-1)
autoxs=AutoXS(nus,"ExoMol","CO") #using ExoMol CO (12C-16O). HITRAN and HITEMP are also supported.  
xsv=autoxs.xsection(1000.0,1.0) #cross section for 1000K, 1bar (cm2)
# Out:
# Warning: CO is interpreted as 12C-16O
# CO/12C-16O/Li2015
# Background atmosphere:  H2
# Reading transition file
# default broadening parameters are used for  71  J lower states in  152  states
# 100%|██████████| 19/19 [00:00<00:00,  4.57it/s]

# %%
plt.plot(nus,xsv) #cm2
plt.xlabel("wavenumber (cm-1)")
plt.ylabel("cross section (cm2)")
# Out:
# Text(0, 0.5, 'cross section (cm2)')

# %% [markdown]
# You can plot the line strengths.

# %%
ls=autoxs.linest(1000.0,1.0) #line strength for 1000K, 1bar (cm)
plt.plot(autoxs.mdb.nu_lines,ls,".")

# %%
from exojax.spec.rtransfer import nugrid
from exojax.spec import AutoRT

# %%
nus,wav,res=nugrid(1900.0,2300.0,40000,"cm-1")
Parr=numpy.logspace(-8,2,100)
Tarr = 500.*(Parr/Parr[-1])**0.02    
autort=AutoRT(nus,1.e5,2.33,Tarr,Parr) #g=1.e5 cm/s2, mmw=2.33
autort.addcia("H2-H2",0.74,0.74)       #CIA, mmr(H)=0.74
autort.addcia("H2-He",0.74,0.25)       #CIA, mmr(He)=0.25
autort.addmol("ExoMol","CO",0.01)      #CO line, mmr(CO)=0.01
# Out:
# nu grid is evenly spaced in log space (ESLOG).
# H2-H2
# H2-He
# Warning: CO is interpreted as 12C-16O
# CO/12C-16O/Li2015
# Background atmosphere:  H2
# Reading transition file
# default broadening parameters are used for  71  J lower states in  152  states
# 100%|██████████| 38/38 [00:15<00:00,  1.66it/s]

# %%
F=autort.rtrun()

# %%
plt.plot(nus,F)
plt.xlabel("wavenumber (cm-1)")
plt.ylabel("flux (erg/s/cm2/cm-1)")
# Out:
# Text(0, 0.5, 'flux (erg/s/cm2/cm-1)')

# %%
plt.plot(nus,F)
plt.xlabel("wavenumber (cm-1)")
plt.ylabel("flux (erg/s/cm2/cm-1)")
# Out:
# Text(0, 0.5, 'flux (erg/s/cm2/cm-1)')

# %%
nusobs=numpy.linspace(1900.0,2300.0,1000,dtype=numpy.float64) #observation wavenumber bin (cm-1)
Fobs=autort.spectrum(nusobs,100000.0,20.0,0.0) #R=100000, vsini=10km/s, RV=0km/s
# Out:
# radiative transfer 0.011783361434936523 s
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-14-3f501feebf17> in <module>
#       1 nusobs=numpy.linspace(1900.0,2300.0,1000,dtype=numpy.float64) #observation wavenumber bin (cm-1)
# ----> 2 Fobs=autort.spectrum(nusobs,100000.0,20.0,0.0) #R=100000, vsini=10km/s, RV=0km/s
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/autospec.py in spectrum(self, nuobs, R, vsini, RV, u1, u2, zeta, betamic, direct)
#     295             ts=time.time()
# --> 296             Frot=response.rigidrot(self.nus,F0,self.vsini,u1=self.u1,u2=self.u2)
#     297             te=time.time()
#
# FilteredStackTrace: RuntimeError: Resource exhausted: Out of memory while trying to allocate 6400160016 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-3f501feebf17> in <module>
#       1 nusobs=numpy.linspace(1900.0,2300.0,1000,dtype=numpy.float64) #observation wavenumber bin (cm-1)
# ----> 2 Fobs=autort.spectrum(nusobs,100000.0,20.0,0.0) #R=100000, vsini=10km/s, RV=0km/s
#
# ~/anaconda3/lib/python3.7/site-packages/exojax-0.0.0-py3.7.egg/exojax/spec/autospec.py in spectrum(self, nuobs, R, vsini, RV, u1, u2, zeta, betamic, direct)
#     294         if len(self.nus)<50000 and direct==True:
#     295             ts=time.time()
# --> 296             Frot=response.rigidrot(self.nus,F0,self.vsini,u1=self.u1,u2=self.u2)
#     297             te=time.time()
#     298             print("rotation",te-ts,"s")
#
# ~/anaconda3/lib/python3.7/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     393       return cpp_jitted_f(*args, **kwargs)
#     394     else:
# --> 395       return cpp_jitted_f(context, *args, **kwargs)
#     396   f_jitted._cpp_jitted_f = cpp_jitted_f
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in cache_miss(_, *args, **kwargs)
#     290         backend=backend,
#     291         name=flat_fun.__name__,
# --> 292         donated_invars=donated_invars)
#     293     out_pytree_def = out_tree()
#     294     out = tree_unflatten(out_pytree_def, out_flat)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1233
#    1234   def bind(self, fun, *args, **params):
# -> 1235     return call_bind(self, fun, *args, **params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1224   tracers = map(top_trace.full_raise, args)
#    1225   with maybe_new_sublevel(top_trace):
# -> 1226     outs = primitive.process(top_trace, fun, tracers, params)
#    1227   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1228
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
# -> 1238     return trace.process_call(self, fun, tracers, params)
#    1239
#    1240   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     596
#     597   def process_call(self, primitive, f, tracers, params):
# --> 598     return primitive.impl(f, *tracers, **params)
#     599   process_map = process_call
#     600
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     577                                *unsafe_map(arg_spec, args))
#     578   try:
# --> 579     return compiled_fun(*args)
#     580   except FloatingPointError:
#     581     assert FLAGS.jax_debug_nans  # compiled_fun can only raise in this case
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _execute_compiled(compiled, avals, handlers, *args)
#     835   device, = compiled.local_devices()
#     836   input_bufs = list(it.chain.from_iterable(device_put(x, device) for x in args if x is not token))
# --> 837   out_bufs = compiled.execute(input_bufs)
#     838   if FLAGS.jax_debug_nans: check_nans(xla_call_p, out_bufs)
#     839   return [handler(*bs) for handler, bs in zip(handlers, _partition_outputs(avals, out_bufs))]
#
# RuntimeError: Resource exhausted: Out of memory while trying to allocate 6400160016 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).

# %%
plt.plot(nus,F)
plt.plot(nusobs,Fobs)
plt.xlabel("wavenumber (cm-1)")
plt.ylabel("flux (erg/s/cm2/cm-1)")

# %%
plt.plot(nus,F)
plt.plot(nusobs,Fobs)
plt.xlim(2100,2110)
plt.ylim(0,450)
plt.xlabel("wavenumber (cm-1)")
plt.ylabel("flux (erg/s/cm2/cm-1)")

# %% [markdown]
# The contribution function

# %%
from exojax.plot.atmplot import plotcf

# %%
cf=plotcf(nus,autort.dtau,Tarr,Parr,autort.dParr)
